# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
#%matplotlib notebook
#import matplotlib.pylab as plt
import matplotlib
matplotlib.style.use('ggplot')
import pandas as pd
import multiprocessing
from joblib import Parallel, delayed
num_cores = multiprocessing.cpu_count()
if num_cores == 32:
    num_cores = 24  # lsst-dev - don't use all the cores, man.
elif num_cores == 8:
    num_cores = 3
elif num_cores == 4:
    num_cores = 2
print num_cores

import seaborn as sns
sns.set(style="whitegrid", palette="pastel", color_codes=True)

pd.options.display.max_columns = 9999
pd.set_option('display.width', 9999)

import warnings
warnings.filterwarnings('ignore')

import diffimTests as dit
# Out:
# 3

# %%
# Set up console so we can reattach via terminal ipython later. See:
# https://stackoverflow.com/questions/19479645/using-ipython-console-along-side-ipython-notebook

# %qtconsole

# Then do `ipython console --existing` in a terminal to connect and have access to same data!
# But note, do not do CTRL-D in that terminal or it will kill the kernel!

# %% [markdown]
# ## New topic: double gaussian psf...

# %%
reload(dit)
psfSize = 21
x = np.arange(-psfSize+1, psfSize, 1)
y = x.copy()
y0, x0 = np.meshgrid(x, y)
psf = dit.psf.doubleGaussian2d(x0, y0, 0, 0, a=0.9, sigma_x=3.0, sigma_y=3.5)
print psf.sum()
dit.plotImageGrid((psf,), clim=(-0.01, 0.01))
# Out:
# 1.0

# %%
dit.plotImageGrid((psf,), clim=(-0.0001, 0.0001))

# %%
psf2 = dit.psf.singleGaussian2d(x0, y0, 0, 0, sigma_x=3.0, sigma_y=3.5, theta=0.)
psf3 = dit.psf.doubleGaussian2d(x0, y0, 0, 0, a=0.8, sigma_x=3.0, sigma_y=3.5)
print dit.afw.arrayToAfwPsf(psf).computeShape()
print dit.afw.arrayToAfwPsf(psf2).computeShape()
print dit.afw.arrayToAfwPsf(psf3).computeShape()
plt.plot(psf[20,:])
plt.plot(psf2[20,:])
plt.plot(psf3[20,:])
# Out:
# (ixx=12.9123732203, iyy=9.48680733984, ixy=0.0)
# (ixx=12.2497431042, iyy=8.99978630007, ixy=-0.0)
# (ixx=13.7640474984, iyy=10.1123404965, ixy=-0.0)

# %% [markdown]
# ## Use `galsim` for Kolmogorov PSF...

# %%
import galsim
#gsp = galsim.GSParams(folding_threshold=1.0/512., maximum_fft_size=12288)
psf = galsim.Kolmogorov(fwhm=3.5*0.2*2.355, flux=1) #, gsparams=gsp)
im = psf.drawImage(method='real_space', scale=0.2)
print im.image.array.size
bounds = im.getBounds()
print bounds, bounds.getXMax()
arr = im.image.array.reshape(bounds.getXMax(), bounds.getXMax())
dit.plotImageGrid((arr,))
# Out:
# 9604
# galsim.BoundsI(1,98,1,98) 98

# %%
print psf.getFWHM()
print dit.afw.arrayToAfwPsf(arr).computeShape()
plt.plot(arr[bounds.getXMax()//2,:])
# Out:
# 1.6485
# (ixx=13.9971286725, iyy=13.9971286725, ixy=0.27901747012)

# %% [markdown]
# ## Now a Moffat...

# %%
reload(dit)

psfSize = 21
x = np.arange(-psfSize+1, psfSize, 1)
y = x.copy()
y0, x0 = np.meshgrid(x, y)
psf = dit.psf.moffat2d(x0, y0, 0, 0, 3.5*2.355)  # fwhm = 2.355 * sigma
print psf.sum()
print dit.afw.arrayToAfwPsf(psf).computeShape()
dit.plotImageGrid((psf,), clim=(-0.01, 0.01))
# Out:
# 1.0
# (ixx=14.1958993231, iyy=14.1958993231, ixy=0.0)

# %%
plt.plot(psf[20,:])
plt.plot(psf2[20,:])

# %% [markdown]
# ## After adding these to `diffimTests.psf.makePsf` and `diffimTests.makeFakeImages`...

# %%
reload(dit)
testObj = dit.diffimTests.DiffimTest(n_sources=500, sourceFluxRange=(2000, 20000), 
                         varFlux2=np.linspace(200, 2000, 50),
                         #varFlux2=np.repeat(500., 50),
                         templateNoNoise=True, skyLimited=True,
                         avoidAllOverlaps=15.)

res = testObj.runTest(returnSources=True)
src = res['sources']
del res['sources']
print res

tmp = dit.catalogToDF(testObj.getCentroidsCatalog(transientsOnly=False))
#dit.sizeme(tmp.tail())
testObj.doPlot(centroidCoord=[tmp.centroid_y.values[300], tmp.centroid_x.values[300]]);
# Out:
# {'ZOGY': {'FP': 2, 'FN': 460, 'TP': 40}, 'ALstack': {'FP': 2, 'FN': 461, 'TP': 39}, 'SZOGY': {'FP': 3, 'FN': 461, 'TP': 39}, 'ALstack_decorr': {'FP': 2, 'FN': 461, 'TP': 39}}

# %%
testObj.doPlotWithDetectionsHighlighted(transientsOnly=True, divideByInput=False, addPresub=True)
plt.xlim(0, 2000)
plt.ylim(-2, 20)
plt.title('Default Gaussian PSFs')
# Out:
# {'ZOGY': {'FP': 2, 'FN': 460, 'TP': 40}, 'ALstack': {'FP': 2, 'FN': 461, 'TP': 39}, 'SZOGY': {'FP': 3, 'FN': 461, 'TP': 39}, 'ALstack_decorr': {'FP': 2, 'FN': 461, 'TP': 39}}

# %%
reload(dit)
testObj2 = dit.diffimTests.DiffimTest(n_sources=500, sourceFluxRange=(2000, 20000), 
                         varFlux2=np.linspace(200, 2000, 50),
                         #varFlux2=np.repeat(500., 50),
                         templateNoNoise=True, skyLimited=True,
                         avoidAllOverlaps=15., psfType='doubleGaussian')

res2 = testObj2.runTest(returnSources=True)
src2 = res2['sources']
del res2['sources']
print res2

testObj2.doPlot(centroidCoord=[tmp.centroid_y.values[300], tmp.centroid_x.values[300]]);
# Out:
# {'ZOGY': {'FP': 3, 'FN': 466, 'TP': 34}, 'ALstack': {'FP': 2, 'FN': 466, 'TP': 34}, 'SZOGY': {'FP': 6, 'FN': 468, 'TP': 32}, 'ALstack_decorr': {'FP': 2, 'FN': 466, 'TP': 34}}

# %%
testObj2.doPlotWithDetectionsHighlighted(transientsOnly=True, divideByInput=False, addPresub=True)
plt.xlim(0, 2000)
plt.ylim(-2, 20)
plt.title('Double Gaussian PSFs')
# Out:
# {'ZOGY': {'FP': 3, 'FN': 466, 'TP': 34}, 'ALstack': {'FP': 2, 'FN': 466, 'TP': 34}, 'SZOGY': {'FP': 6, 'FN': 468, 'TP': 32}, 'ALstack_decorr': {'FP': 2, 'FN': 466, 'TP': 34}}

# %%
reload(dit)
testObj3 = dit.diffimTests.DiffimTest(n_sources=500, sourceFluxRange=(2000, 20000), 
                         varFlux2=np.linspace(200, 2000, 50),
                         #varFlux2=np.repeat(500., 50),
                         templateNoNoise=True, skyLimited=True,
                         avoidAllOverlaps=15., psfType='moffat')

res3 = testObj3.runTest(returnSources=True)
src3 = res3['sources']
del res3['sources']
print res3

testObj3.doPlot(centroidCoord=[tmp.centroid_y.values[300], tmp.centroid_x.values[300]]);
# Out:
# {'ZOGY': {'FP': 4, 'FN': 465, 'TP': 35}, 'ALstack': {'FP': 3, 'FN': 465, 'TP': 35}, 'SZOGY': {'FP': 4, 'FN': 465, 'TP': 35}, 'ALstack_decorr': {'FP': 3, 'FN': 465, 'TP': 35}}

# %%
testObj3.doPlotWithDetectionsHighlighted(transientsOnly=True, divideByInput=False, addPresub=True)
plt.xlim(0, 2000)
plt.ylim(-2, 20)
plt.title('Moffat PSFs')
# Out:
# {'ZOGY': {'FP': 4, 'FN': 465, 'TP': 35}, 'ALstack': {'FP': 3, 'FN': 465, 'TP': 35}, 'SZOGY': {'FP': 4, 'FN': 465, 'TP': 35}, 'ALstack_decorr': {'FP': 3, 'FN': 465, 'TP': 35}}

# %% [markdown]
# Kolmogorov works now, but is slow and there's still an issue with the A&L(dec) - ZOGY image.
# Seems to be because of a 0.5-pixel offset in the psf.

# %%
reload(dit)
testObj4 = dit.diffimTests.DiffimTest(n_sources=500, sourceFluxRange=(2000, 20000), 
                         varFlux2=np.linspace(200, 2000, 50),
                         #varFlux2=np.repeat(500., 50),
                         templateNoNoise=True, skyLimited=True,
                         avoidAllOverlaps=15., psfType='kolmogorov')

res4 = testObj4.runTest(returnSources=True)
src4 = res4['sources']
del res4['sources']
print res4
# Out:
# {'ZOGY': {'FP': 31, 'FN': 50, 'TP': 0}, 'ALstack': {'FP': 3, 'FN': 20, 'TP': 30}, 'SZOGY': {'FP': 25, 'FN': 50, 'TP': 0}, 'ALstack_decorr': {'FP': 3, 'FN': 21, 'TP': 29}}

# %%
tmp = dit.catalogToDF(testObj.getCentroidsCatalog(transientsOnly=False))
testObj4.doPlot(centroidCoord=[tmp.centroid_y.values[300], tmp.centroid_x.values[300]]);
#testObj4.doPlot();

# %%
print np.unravel_index(np.argmax(testObj.im2.psf), testObj.im2.psf.shape)
print np.unravel_index(np.argmax(testObj2.im2.psf), testObj2.im2.psf.shape)
print np.unravel_index(np.argmax(testObj3.im2.psf), testObj3.im2.psf.shape)
print np.unravel_index(np.argmax(testObj4.im2.psf), testObj4.im2.psf.shape)

print dit.afw.arrayToAfwPsf(testObj.im2.psf).computeShape()
print dit.afw.arrayToAfwPsf(testObj2.im2.psf).computeShape()
print dit.afw.arrayToAfwPsf(testObj3.im2.psf).computeShape()
print dit.afw.arrayToAfwPsf(testObj4.im2.psf).computeShape()

#dit.plotImageGrid((testObj.im2.psf, testObj2.im2.psf, testObj3.im2.psf, testObj4.im2.psf,))
# Out:
# (20, 20)
# (20, 20)
# (20, 20)
# (20, 20)
# (ixx=4.03994623804, iyy=4.03994623804, ixy=-0.799989278877)
# (ixx=4.90711259462, iyy=4.90711259462, ixy=-0.971716519198)
# (ixx=4.63417624379, iyy=4.63417624379, ixy=-0.0)
# (ixx=4.54343857395, iyy=4.54343857395, ixy=-0.0)

# %%
dit.plotImageGrid((testObj.ALres.decorrelationKernel, testObj2.ALres.decorrelationKernel,
                  testObj3.ALres.decorrelationKernel, testObj4.ALres.decorrelationKernel,))

# %% [markdown]
# This difference (below) is due to an issue probably with an offset in the PSFs.

# %%
testObj4.doPlotWithDetectionsHighlighted(transientsOnly=True, divideByInput=False, addPresub=True)
plt.xlim(0, 2000)
plt.ylim(-2, 20)
plt.title('Kolmogorov PSFs')
# Out:
# {'ZOGY': {'FP': 10, 'FN': 472, 'TP': 28}, 'ALstack': {'FP': 7, 'FN': 469, 'TP': 31}, 'SZOGY': {'FP': 13, 'FN': 474, 'TP': 26}, 'ALstack_decorr': {'FP': 7, 'FN': 469, 'TP': 31}}

# %%
print dit.psf.computeMoments(testObj.im1.psf)
print dit.psf.computeMoments(testObj2.im1.psf)
print dit.psf.computeMoments(testObj3.im1.psf)
print dit.psf.computeMoments(testObj4.im1.psf)
# Out:
# (20.0, 20.000000000000004)
# (20.0, 20.000000000000007)
# (20.0, 20.0)
# (20.0, 20.0)

# %%
print dit.psf.computeMoments(testObj.im2.psf)
print dit.psf.computeMoments(testObj2.im2.psf)
print dit.psf.computeMoments(testObj3.im2.psf)
print dit.psf.computeMoments(testObj4.im2.psf)
# Out:
# (20.0, 20.000000000000004)
# (20.0, 20.0)
# (20.0, 20.0)
# (20.0, 20.0)

# %% [markdown]
# # Now for "real" psfs from real images. Try this:

# %%
import lsst.afw.image as afwImage
# This image was a simulated image written out previously...
im = afwImage.ExposureF('test_imageDifference/test_dr1/deepDiff/im2/diffexp.fits')
print im.getBBox()
psf = im.getPsf()
print dit.afw.afwPsfToShape(psf, im)
print dit.afw.afwPsfToShape(psf, im).getDeterminantRadius()
dit.plotImageGrid((dit.afw.afwPsfToArray(psf, im),))
# Out:
# Box2I((0, 0), (511, 511))
# (ixx=4.2937886539, iyy=4.68256779165, ixy=-1.00958235705)
# 2.0901753005

# %%
import os
import lsst.afw.image as afwImage
import diffimTests as dit

afwData = os.getenv('AFWDATA_DIR')
im = afwImage.ExposureF(afwData + '/CFHT/D4/cal-53535-i-797722_1.fits')
print im.getBBox()
dit.plotImageGrid((im.getMaskedImage().getImage(),), imScale=8.)
# Out:
# Box2I((0, 0), (2111, 4643))

# %%
res = dit.tasks.doMeasurePsf(im, detectThresh=10.0, startSize=6.0, spatialOrder=2)
psf = res.psf #im.getPsf()
print dit.afw.afwPsfToShape(psf)
dit.plotImageGrid((dit.afw.afwPsfToArray(psf, im),
                   dit.afw.afwPsfToArray(psf, coord=[100,100]),
                  dit.afw.afwPsfToArray(psf, coord=[1500,4000])), imScale=3.)
# Out:
# (ixx=2.98711664574, iyy=4.45245174118, ixy=-0.900905346003)

# %%
print type(psf)
psf.writeFits('cal-53535-i-797722_1_psf.fits')

import lsst.afw.detection as afwDet
psf2 = afwDet.Psf.readFits('cal-53535-i-797722_1_psf.fits')
print dit.afw.afwPsfToShape(psf2)
dit.plotImageGrid((dit.afw.afwPsfToArray(psf2, im),
                   dit.afw.afwPsfToArray(psf2, coord=[100,100]),
                  dit.afw.afwPsfToArray(psf2, coord=[1500,4000])), imScale=3.)
# Out:
# <class 'lsst.meas.extensions.psfex.psfexLib.PsfexPsf'>
# (ixx=2.98711664574, iyy=4.45245174118, ixy=-0.900905346003)

# %%
shape = dit.afw.afwPsfToShape(psf)
print shape
print shape.getTraceRadius() * 2.
shape.getDeterminantRadius() * 2.
# Out:
# (ixx=2.98711664574, iyy=4.45245174118, ixy=-0.900905346003)
# 3.85734841229
# 3.759727489503463

# %%
import os
afwData = os.getenv('AFWDATA_DIR')
filename = afwData + '/CFHT/D4/cal-53535-i-797722_1.fits'
psf = dit.psf.loadPsf(filename)
dit.plotImageGrid((psf,))

# %%
import diffimTests as dit
import glob, os

afwData = os.getenv('AFWDATA_DIR')
drpData = os.getenv('HOME') + '/DATA/'

filenames = glob.glob(afwData + '/CFHT/D4/*.fits')
# PsfEx doesn't seem to work well on many of the imsim simulated images.
filenames.extend(glob.glob(afwData + '/ImSim/postISR/v85751839-fr/s1/R23/S11/*.fits'))
filenames.extend(glob.glob(drpData + '/validation_data_decam/data/*/calexp/calexp*.fits'))
filenames.extend(glob.glob(drpData + './validation_data_cfht/data/calexp/06AL01/D3/2006-*/r/calexp*.fits'))

psfs = {}
for filename in filenames:
    if filename.find('small') > 0:
        continue
    print filename
    try:
        psfs[filename], source = dit.psf.loadPsf(filename, asArray=False, forceReMeasure=True)
        print source, dit.afw.afwPsfToShape(psfs[filename])
    except Exception as e:
        print e
# Out:
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_1.fits
# measured (ixx=2.94816469033, iyy=4.45738762979, ixy=-0.92068890118)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_1_tmpl.fits
# measured (ixx=3.64391908276, iyy=4.02471747415, ixy=-0.18133585555)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_2.fits
# measured (ixx=2.55937027591, iyy=3.93038772842, ixy=-0.502375296895)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_2_tmpl.fits
# measured (ixx=3.39782342322, iyy=3.68717056065, ixy=-0.0742932363751)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_3.fits
# measured (ixx=2.28475730023, iyy=3.45907719925, ixy=-0.183215104756)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_3_tmpl.fits
# measured (ixx=3.28642181602, iyy=3.48807236631, ixy=0.0248749106604)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_4.fits
# measured (ixx=2.25125876016, iyy=3.20152947724, ixy=-0.00788442022972)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_4_tmpl.fits
# measured (ixx=3.31424263373, iyy=3.54658965669, ixy=0.0621242181868)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_5.fits
# measured (ixx=2.14393005913, iyy=3.0994952134, ixy=0.00782952305326)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_5_tmpl.fits
# measured (ixx=3.18981105562, iyy=3.43884477237, ixy=0.0734010349478)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_6.fits
# measured (ixx=2.16446894133, iyy=3.13680298165, ixy=-0.0105360601912)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_6_tmpl.fits
# measured (ixx=3.27248563399, iyy=3.55102064854, ixy=0.0804140879974)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_7.fits
# measured (ixx=2.28916999157, iyy=3.23967383092, ixy=0.00980102239835)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_7_tmpl.fits
# measured (ixx=3.42354785192, iyy=3.73134000284, ixy=0.134218329568)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_8.fits
# measured (ixx=2.67925599348, iyy=3.7078902312, ixy=0.0286072444754)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_8_tmpl.fits
# measured (ixx=3.77083590565, iyy=4.13977614537, ixy=0.182557449084)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_9.fits
# measured (ixx=2.983060191, iyy=3.53317399107, ixy=0.061374258773)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_9_tmpl.fits
# measured (ixx=4.04627712839, iyy=4.42662492418, ixy=0.242633488212)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C00.fits
# measured (ixx=5.04335410682, iyy=4.89230392718, ixy=-0.364013054297)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C01.fits
#
#   File "src/PsfexPsf.cc", line 192, in virtual std::shared_ptr<afw::detection::Psf::Image> lsst::meas::extensions::psfex::PsfexPsf::_doComputeImage(const afw::geom::Point2D &, const afw::image::Color &, const afw::geom::Point2D &) const
#     Only spatial variation (ndim == 2) is supported; saw 0 {0}
# lsst::pex::exceptions::InvalidParameterError: 'Only spatial variation (ndim == 2) is supported; saw 0'
#
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C02.fits
# measured (ixx=5.34745399293, iyy=5.23054323642, ixy=-0.571231836137)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C03.fits
# measured (ixx=5.03341091877, iyy=4.93709582266, ixy=-0.441470336847)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C04.fits
# measured (ixx=3.56990855808, iyy=3.64443664319, ixy=-0.360848155204)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C05.fits
# measured (ixx=5.03601680744, iyy=4.92022908613, ixy=-0.469965282935)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C06.fits
# measured (ixx=4.99776067297, iyy=4.95325143788, ixy=-0.555267479467)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C07.fits
# measured (ixx=5.10685371317, iyy=5.12154570107, ixy=-0.551217798176)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C10.fits
#
#   File "src/PsfexPsf.cc", line 192, in virtual std::shared_ptr<afw::detection::Psf::Image> lsst::meas::extensions::psfex::PsfexPsf::_doComputeImage(const afw::geom::Point2D &, const afw::image::Color &, const afw::geom::Point2D &) const
#     Only spatial variation (ndim == 2) is supported; saw 0 {0}
# lsst::pex::exceptions::InvalidParameterError: 'Only spatial variation (ndim == 2) is supported; saw 0'
#
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C11.fits
# measured (ixx=5.2626924905, iyy=4.48255100868, ixy=0.436053057509)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C12.fits
# measured (ixx=5.17191482846, iyy=4.4792991335, ixy=0.477713989604)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C13.fits
#
#   File "src/PsfexPsf.cc", line 192, in virtual std::shared_ptr<afw::detection::Psf::Image> lsst::meas::extensions::psfex::PsfexPsf::_doComputeImage(const afw::geom::Point2D &, const afw::image::Color &, const afw::geom::Point2D &) const
#     Only spatial variation (ndim == 2) is supported; saw 0 {0}
# lsst::pex::exceptions::InvalidParameterError: 'Only spatial variation (ndim == 2) is supported; saw 0'
#
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C14.fits
#
#   File "src/PsfexPsf.cc", line 192, in virtual std::shared_ptr<afw::detection::Psf::Image> lsst::meas::extensions::psfex::PsfexPsf::_doComputeImage(const afw::geom::Point2D &, const afw::image::Color &, const afw::geom::Point2D &) const
#     Only spatial variation (ndim == 2) is supported; saw 0 {0}
# lsst::pex::exceptions::InvalidParameterError: 'Only spatial variation (ndim == 2) is supported; saw 0'
#
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C15.fits
#
#   File "src/PsfexPsf.cc", line 192, in virtual std::shared_ptr<afw::detection::Psf::Image> lsst::meas::extensions::psfex::PsfexPsf::_doComputeImage(const afw::geom::Point2D &, const afw::image::Color &, const afw::geom::Point2D &) const
#     Only spatial variation (ndim == 2) is supported; saw 0 {0}
# lsst::pex::exceptions::InvalidParameterError: 'Only spatial variation (ndim == 2) is supported; saw 0'
#
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C16.fits
#
#   File "src/PsfexPsf.cc", line 192, in virtual std::shared_ptr<afw::detection::Psf::Image> lsst::meas::extensions::psfex::PsfexPsf::_doComputeImage(const afw::geom::Point2D &, const afw::image::Color &, const afw::geom::Point2D &) const
#     Only spatial variation (ndim == 2) is supported; saw 0 {0}
# lsst::pex::exceptions::InvalidParameterError: 'Only spatial variation (ndim == 2) is supported; saw 0'
#
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C17.fits
# measured (ixx=5.54171230277, iyy=4.43925924201, ixy=0.632788221069)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_10.fits
# measured (ixx=3.40167844793, iyy=3.44357074053, ixy=-0.193766229303)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_11.fits
# measured (ixx=3.38720825551, iyy=3.49596664666, ixy=-0.138866229614)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_12.fits
# measured (ixx=3.28315881509, iyy=3.28044814361, ixy=-0.118150633583)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_13.fits
# measured (ixx=3.1887759078, iyy=2.94503596708, ixy=-0.0987160274348)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_14.fits
# measured (ixx=3.32253031389, iyy=3.28607042678, ixy=-0.110764929366)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_15.fits
# measured (ixx=3.42787853046, iyy=3.33388160664, ixy=-0.111662204557)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_16.fits
# measured (ixx=3.52609655639, iyy=3.59321352769, ixy=-0.169898592702)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_17.fits
# measured (ixx=3.36275019096, iyy=3.56262864446, ixy=-0.109322529049)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_18.fits
# measured (ixx=3.18980381417, iyy=3.34047169619, ixy=-0.0917185048035)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_10.fits
# measured (ixx=6.57639816375, iyy=6.17225892671, ixy=0.101245699692)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_11.fits
# measured (ixx=6.59608901312, iyy=5.97215277985, ixy=0.136754585689)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_12.fits
# measured (ixx=6.6553270903, iyy=5.94912497659, ixy=-0.143786167158)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_13.fits
# measured (ixx=7.0012957531, iyy=6.24833384395, ixy=-0.031882182572)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_14.fits
# measured (ixx=6.86263648714, iyy=6.34001701393, ixy=-0.0265183818192)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_15.fits
# measured (ixx=6.90935083298, iyy=6.29735575355, ixy=0.023696288481)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_16.fits
# measured (ixx=6.71516512692, iyy=6.1547918659, ixy=0.124887729445)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_17.fits
# measured (ixx=6.53713661228, iyy=6.02938701989, ixy=0.168681435199)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_18.fits
# measured (ixx=6.39355167331, iyy=6.08884164776, ixy=-0.113318194289)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-05-20/r/calexp-849375-12.fits
# measured (ixx=5.9499096786, iyy=6.18960813367, ixy=0.231962318226)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-05-20/r/calexp-849375-13.fits
# measured (ixx=6.00295163447, iyy=6.30849343732, ixy=0.166765062081)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-05-20/r/calexp-849375-14.fits
# measured (ixx=6.00507708972, iyy=6.22403927679, ixy=0.123370545201)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-05-20/r/calexp-849375-21.fits
# measured (ixx=5.74661871627, iyy=6.21675826397, ixy=0.121065024952)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-05-20/r/calexp-849375-22.fits
# measured (ixx=5.88440971107, iyy=6.38369718929, ixy=0.391448320054)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-05-20/r/calexp-849375-23.fits
# measured (ixx=6.82290123674, iyy=6.85868733076, ixy=0.0165813171521)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-06-02/r/calexp-850587-12.fits
# measured (ixx=2.70521352256, iyy=3.03692456155, ixy=0.234672293489)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-06-02/r/calexp-850587-13.fits
# measured (ixx=2.73882168715, iyy=3.03432259017, ixy=0.19993205002)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-06-02/r/calexp-850587-14.fits
# measured (ixx=2.72578810676, iyy=3.01407640538, ixy=0.171055456475)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-06-02/r/calexp-850587-21.fits
# measured (ixx=2.71222603721, iyy=3.01497370233, ixy=0.148536650187)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-06-02/r/calexp-850587-22.fits
# measured (ixx=2.68470007339, iyy=3.07394285716, ixy=0.14901349939)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-06-02/r/calexp-850587-23.fits
# measured (ixx=2.76653352431, iyy=3.05562776027, ixy=0.12507169608)

# %%
import diffimTests as dit
import glob, os

afwData = os.getenv('AFWDATA_DIR')
drpData = os.getenv('HOME') + '/DATA/'

#fnames = glob.glob('./psfLib/*.fits')
#fnames = [fn.replace('_psf', '') for fn in fnames]
filenames = glob.glob(afwData + '/CFHT/D4/*.fits')
# PsfEx doesn't seem to work well on the imsim simulated images.
filenames.extend(glob.glob(afwData + '/ImSim/postISR/v85751839-fr/s1/R23/S11/*.fits'))
filenames.extend(glob.glob(drpData + '/validation_data_decam/data/*/calexp/calexp*.fits'))
filenames.extend(glob.glob(drpData + './validation_data_cfht/data/calexp/06AL01/D3/2006-*/r/calexp*.fits'))

psfs = {}
for filename in filenames:
    #print filename
    try:
        psf, source = dit.psf.loadPsf(filename, asArray=False)
        if psf is not None:
            print filename, dit.afw.afwPsfToShape(psf)
            psfs[filename] = psf
    except Exception as e:
        pass
        #print e
        
print len(psfs)
# Out:
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_1.fits (ixx=2.94816469033, iyy=4.45738762979, ixy=-0.92068890118)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_1_tmpl.fits (ixx=3.64391908276, iyy=4.02471747415, ixy=-0.18133585555)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_2.fits (ixx=2.55937027591, iyy=3.93038772842, ixy=-0.502375296895)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_2_tmpl.fits (ixx=3.39782342322, iyy=3.68717056065, ixy=-0.0742932363751)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_3.fits (ixx=2.28475730023, iyy=3.45907719925, ixy=-0.183215104756)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_3_tmpl.fits (ixx=3.28642181602, iyy=3.48807236631, ixy=0.0248749106604)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_4.fits (ixx=2.25125876016, iyy=3.20152947724, ixy=-0.00788442022972)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_4_tmpl.fits (ixx=3.31424263373, iyy=3.54658965669, ixy=0.0621242181868)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_5.fits (ixx=2.14393005913, iyy=3.0994952134, ixy=0.00782952305326)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_5_tmpl.fits (ixx=3.18981105562, iyy=3.43884477237, ixy=0.0734010349478)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_6.fits (ixx=2.16446894133, iyy=3.13680298165, ixy=-0.0105360601912)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_6_tmpl.fits (ixx=3.27248563399, iyy=3.55102064854, ixy=0.0804140879974)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_7.fits (ixx=2.28916999157, iyy=3.23967383092, ixy=0.00980102239835)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_7_tmpl.fits (ixx=3.42354785192, iyy=3.73134000284, ixy=0.134218329568)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_8.fits (ixx=2.67925599348, iyy=3.7078902312, ixy=0.0286072444754)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_8_tmpl.fits (ixx=3.77083590565, iyy=4.13977614537, ixy=0.182557449084)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_9.fits (ixx=2.983060191, iyy=3.53317399107, ixy=0.061374258773)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_9_tmpl.fits (ixx=4.04627712839, iyy=4.42662492418, ixy=0.242633488212)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C00.fits (ixx=5.04335410682, iyy=4.89230392718, ixy=-0.364013054297)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C02.fits (ixx=5.34745399293, iyy=5.23054323642, ixy=-0.571231836137)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C03.fits (ixx=5.03341091877, iyy=4.93709582266, ixy=-0.441470336847)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C04.fits (ixx=3.56990855808, iyy=3.64443664319, ixy=-0.360848155204)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C05.fits (ixx=5.03601680744, iyy=4.92022908613, ixy=-0.469965282935)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C06.fits (ixx=4.99776067297, iyy=4.95325143788, ixy=-0.555267479467)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C07.fits (ixx=5.10685371317, iyy=5.12154570107, ixy=-0.551217798176)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C11.fits (ixx=5.2626924905, iyy=4.48255100868, ixy=0.436053057509)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C12.fits (ixx=5.17191482846, iyy=4.4792991335, ixy=0.477713989604)
# /Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/ImSim/postISR/v85751839-fr/s1/R23/S11/C17.fits (ixx=5.54171230277, iyy=4.43925924201, ixy=0.632788221069)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_10.fits (ixx=3.40167844793, iyy=3.44357074053, ixy=-0.193766229303)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_11.fits (ixx=3.38720825551, iyy=3.49596664666, ixy=-0.138866229614)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_12.fits (ixx=3.28315881509, iyy=3.28044814361, ixy=-0.118150633583)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_13.fits (ixx=3.1887759078, iyy=2.94503596708, ixy=-0.0987160274348)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_14.fits (ixx=3.32253031389, iyy=3.28607042678, ixy=-0.110764929366)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_15.fits (ixx=3.42787853046, iyy=3.33388160664, ixy=-0.111662204557)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_16.fits (ixx=3.52609655639, iyy=3.59321352769, ixy=-0.169898592702)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_17.fits (ixx=3.36275019096, iyy=3.56262864446, ixy=-0.109322529049)
# /Users/dreiss/DATA//validation_data_decam/data/0176837/calexp/calexp-0176837_18.fits (ixx=3.18980381417, iyy=3.34047169619, ixy=-0.0917185048035)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_10.fits (ixx=6.57639816375, iyy=6.17225892671, ixy=0.101245699692)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_11.fits (ixx=6.59608901312, iyy=5.97215277985, ixy=0.136754585689)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_12.fits (ixx=6.6553270903, iyy=5.94912497659, ixy=-0.143786167158)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_13.fits (ixx=7.0012957531, iyy=6.24833384395, ixy=-0.031882182572)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_14.fits (ixx=6.86263648714, iyy=6.34001701393, ixy=-0.0265183818192)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_15.fits (ixx=6.90935083298, iyy=6.29735575355, ixy=0.023696288481)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_16.fits (ixx=6.71516512692, iyy=6.1547918659, ixy=0.124887729445)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_17.fits (ixx=6.53713661228, iyy=6.02938701989, ixy=0.168681435199)
# /Users/dreiss/DATA//validation_data_decam/data/0176846/calexp/calexp-0176846_18.fits (ixx=6.39355167331, iyy=6.08884164776, ixy=-0.113318194289)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-05-20/r/calexp-849375-12.fits (ixx=5.9499096786, iyy=6.18960813367, ixy=0.231962318226)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-05-20/r/calexp-849375-13.fits (ixx=6.00295163447, iyy=6.30849343732, ixy=0.166765062081)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-05-20/r/calexp-849375-14.fits (ixx=6.00507708972, iyy=6.22403927679, ixy=0.123370545201)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-05-20/r/calexp-849375-21.fits (ixx=5.74661871627, iyy=6.21675826397, ixy=0.121065024952)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-05-20/r/calexp-849375-22.fits (ixx=5.88440971107, iyy=6.38369718929, ixy=0.391448320054)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-05-20/r/calexp-849375-23.fits (ixx=6.82290123674, iyy=6.85868733076, ixy=0.0165813171521)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-06-02/r/calexp-850587-12.fits (ixx=2.70521352256, iyy=3.03692456155, ixy=0.234672293489)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-06-02/r/calexp-850587-13.fits (ixx=2.73882168715, iyy=3.03432259017, ixy=0.19993205002)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-06-02/r/calexp-850587-14.fits (ixx=2.72578810676, iyy=3.01407640538, ixy=0.171055456475)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-06-02/r/calexp-850587-21.fits (ixx=2.71222603721, iyy=3.01497370233, ixy=0.148536650187)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-06-02/r/calexp-850587-22.fits (ixx=2.68470007339, iyy=3.07394285716, ixy=0.14901349939)
# /Users/dreiss/DATA/./validation_data_cfht/data/calexp/06AL01/D3/2006-06-02/r/calexp-850587-23.fits (ixx=2.76653352431, iyy=3.05562776027, ixy=0.12507169608)
# 58

# %%
psftmp = [dit.afw.afwPsfToArray(psfs[key]) for key in psfs]
psftitles = [os.path.basename(key) for key in psfs]
psftitles = [t for i,t in enumerate(psftitles) if psftmp[i] is not None]
psftmp = [p for p in psftmp if p is not None]
print len(psftmp)
#print psftitles
dit.plotImageGrid(psftmp, titles=psftitles)
# Out:
# 58

# %%
print [p[2,20] for p in psftmp]
# Out:
# [1.2173216418887023e-05, 4.3942891352344304e-06, 2.4577093427069485e-05, 3.2879343052627519e-05, 9.006751497508958e-06, 3.0170473110047169e-05, 0.0001870377454906702, 7.333381290663965e-06, -3.8410082197515294e-05, 6.6732478444464505e-05, -6.5534986788406968e-05, -1.6137440979946405e-05, -5.4239466408034787e-05, 7.02538454788737e-05, -1.2948247785971034e-05, 5.9170229178562295e-06, -7.3804068961180747e-05, -1.0409128208266338e-06, 3.0587594665121287e-05, -1.3578855941887014e-05, 2.0596151443896815e-05, -5.9130466070200782e-06, -0.00014825211837887764, 2.3813077859813347e-05, -0.00010344671318307519, 2.3191390937427059e-05, 5.2038235480722506e-06, -0.00021368361194618046, 1.9561690351110883e-05, 3.7934973079245538e-05, -1.7904139895108528e-06, -8.9519962784834206e-05, 6.7771368776448071e-05, 0.00018110223754774779, 5.2710271120304242e-05, 3.2349405955756083e-05, -8.0632235039956868e-06, 1.516520882205441e-07, 1.0832367479451932e-05, 2.0386041796882637e-05, 8.253090527432505e-06, -5.4026422731112689e-05, 8.7560165411559865e-06, 8.3351023931754753e-06, -2.9118793463567272e-05, 1.6365846022381447e-05, -2.5881266992655583e-05, -6.0915186622878537e-05, -4.0964780055219308e-05, -7.5692943937610835e-05, -2.9431623261189088e-05, 1.6349382349289954e-05, 0.00019392480317037553, 2.5167526473524049e-05, 4.7772678044566419e-06, -2.3941793187987059e-05, 2.295543163199909e-05, -8.4256877016741782e-05]

# %% [markdown]
# Are the negative regions surrounding some PSFs going to be a problem?
#
# Seems a pretty small effect.

# %%
plt.plot(psftmp[8][20,:])
plt.plot(psftmp[10][20,:])
plt.plot(psftmp[12][20,:])
plt.plot(psftmp[50][20,:])

# %% [markdown]
# ## OK now let's figure out how to make the fake image generator use the real PSFS.
#
# Still needs work, I think there's a 1-pixel offset.
#
# Also, need to be able to pass different PSFs for template and science (right now it uses the same one!)
#
# Question - how and whether to use spatial variation.

# %%
filename = '/Users/dreiss/lsstsw/stack/DarwinX86/afwdata/2.2016.10+7/CFHT/D4/cal-53535-i-797722_1.fits'
psf, source = dit.psf.loadPsf(filename, asArray=False)
print type(psf)
from lsst.afw.detection import Psf
print isinstance(psf, Psf)
psfImg = dit.afw.afwPsfToArray(psf)
print type(psfImg)
print isinstance(psfImg, np.ndarray)
psfImg2 = dit.afw.afwPsfToArray(psf, centroid=[0.5, 0.5])
dit.plotImageGrid((psf, psfImg, psfImg2, psfImg2-psfImg))
# Out:
# <class 'lsst.afw.detection.detectionLib.Psf'>
# True
# <type 'numpy.ndarray'>
# True

# %%
reload(dit)
testObj5 = dit.diffimTests.DiffimTest(n_sources=500, sourceFluxRange=(2000, 20000), 
                         varFlux2=np.linspace(200, 2000, 50),
                         #varFlux2=np.repeat(500., 50),
                         templateNoNoise=True, skyLimited=True,
                         avoidAllOverlaps=15., psfType=psf)

res5 = testObj5.runTest(returnSources=True)
src5 = res5['sources']
del res5['sources']
print res5

testObj5.doPlot(centroidCoord=[tmp.centroid_y.values[300], tmp.centroid_x.values[300]]);
# Out:
# {'ZOGY': {'FP': 12, 'FN': 473, 'TP': 27}, 'ALstack': {'FP': 13, 'FN': 473, 'TP': 27}, 'SZOGY': {'FP': 14, 'FN': 473, 'TP': 27}, 'ALstack_decorr': {'FP': 14, 'FN': 474, 'TP': 26}}

# %%
testObj5.doPlotWithDetectionsHighlighted(transientsOnly=True, divideByInput=False, addPresub=True)
plt.xlim(0, 2000)
plt.ylim(-2, 20)
plt.title('Real PSF')
# Out:
# {'ZOGY': {'FP': 12, 'FN': 473, 'TP': 27}, 'ALstack': {'FP': 13, 'FN': 473, 'TP': 27}, 'SZOGY': {'FP': 14, 'FN': 473, 'TP': 27}, 'ALstack_decorr': {'FP': 14, 'FN': 474, 'TP': 26}}
