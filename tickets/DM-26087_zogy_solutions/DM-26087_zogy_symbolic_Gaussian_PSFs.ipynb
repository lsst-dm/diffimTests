# %% [markdown]
# # Zogy PSF and matching kernel of Gaussian image PSFs

# %% [markdown]
# We try to integrate symbolically the 1D case. It did not work.

# %% [markdown]
# ### Notation:
#
# $N_1$, $N_2$: Input images.
#
# $c_1$, $c_2$: Matching kernels for the input images $N_1$ and $N_2$.
#
# $P_1$, $P_2$: PSFs of the input images $N_1$ and $N_2$.
#
# $P_d$ : the PSF of the difference image, the result of the PSF matching for both images.
#
# $\sigma_1$, $\sigma_2$: The PSF sigma (width) of Gaussian image PSFs in _image space_.
#
# We use the terms "Fourier space" and "image space". "Pixel" can refer to pixellated values in either space.
#
# --------

# %% [markdown]
# All quantities are in frequency space unless stated otherwise. In Fourier space, same noise level, same photometric calibration in the two input images, the Zogy difference image can be written as:

# %% [markdown]
# $$D = \frac{P_2}
# {\sqrt{|P_2|^2 + |P_1}|^2}
# N_1 - \frac{P_1}
# {\sqrt{|P_2|^2 + |P_1|^2}} N_2
# = c_1 N_1 - c_2 N_2$$

# %% [markdown]
# $$P_d = \sqrt{2}\frac{P_1 P_2}{\sqrt{|P_1|^2 + |P_2|^2}}$$

# %% [markdown]
# Here, we consider perfect Gaussian input PSFs. In this, case the Fourier transforms are all real and positive (Fourier transform of Gaussians), so we can write:

# %% [markdown]
# $$c_1 \sim \frac{1}{\sqrt{1 + \left(\frac{P_1}{P_2}\right)^2}}$$

# %% [markdown]
# $$P_d \sim \frac{1}{\sqrt{\frac{1}{P_1^2} + \frac{1}{P_2^2}}}$$

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import scipy.integrate as s_int
import numpy as np
import sympy as sp

# %%
pi2 = np.pi * np.pi
x, k = sp.symbols('x k', real=True)
s1, s2 = sp.symbols('sigma1 sigma2', positive=True)

# %%
# Normalized PSF in 1D in real space
# The normalized 2D PSF is the product of two 1D
gPsf = 1/(sp.sqrt(2*sp.pi)*s1)*sp.exp(-x**2/(2*s1**2))
display(gPsf)
# Out:
# sqrt(2)*exp(-x**2/(2*sigma1**2))/(2*sqrt(pi)*sigma1)

# %%
# The Fourier transform of the Gaussian PSF
ftPsf = sp.fourier_transform(gPsf, x, k)
display(ftPsf)
# Out:
# exp(-2*pi**2*k**2*sigma1**2)

# %% [markdown]
# ## Symbolic solution
#
# Based on symbolic Fourier transform tables, these functions are not expected to have closed forms. We try to integrate in the 1D case.
#
# Try the symbolic fourier transform of $c_1$, $c_2$ or $P_d$. Let's try with sympy.
#
# We tried the Fourier transform commands and to integrate directly the cosine term exploiting the symmetry and realness of the functions.
#
# The commands either do not do anything useful or we could not wait long enough...

# %%
# c1, c2 are this kind of expressions, 
fc1 = 1/sp.sqrt(1+ (ftPsf.subs({s1 : 2})/ftPsf.subs({s1 : 1}))**2)
fc2 = 1/sp.sqrt(1+ (ftPsf.subs({s1 : 1})/ftPsf.subs({s1 : 2}))**2)
display(fc1)
display(fc2)
# Out:
# 1/sqrt(1 + exp(-12*pi**2*k**2))
# 1/sqrt(exp(12*pi**2*k**2) + 1)

# %%
sp.fourier_transform(fc1, k, x)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-89aaaf06a95d> in <module>
# ----> 1 sp.fourier_transform(fc1, k, x)
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/transforms.py in fourier_transform(f, x, k, **hints)
#    1405     mellin_transform, laplace_transform
#    1406     """
# -> 1407     return FourierTransform(f, x, k).doit(**hints)
#    1408
#    1409
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/transforms.py in doit(self, **hints)
#     119             try:
#     120                 return self._compute_transform(self.function,
# --> 121                     self.function_variable, self.transform_variable, **hints)
#     122             except IntegralTransformError:
#     123                 pass
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/transforms.py in _compute_transform(self, f, x, k, **hints)
#    1344         return _fourier_transform(f, x, k,
#    1345                                   self.a(), self.b(),
# -> 1346                                   self.__class__._name, **hints)
#    1347
#    1348     def _as_integral(self, f, x, k):
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/transforms.py in wrapper(*args, **kwargs)
#     204         def wrapper(*args, **kwargs):
#     205             noconds = kwargs.pop('noconds', default)
# --> 206             res = func(*args, **kwargs)
#     207             if noconds:
#     208                 return res[0]
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/transforms.py in _fourier_transform(f, x, k, a, b, name, simplify)
#    1311     """
#    1312     from sympy import exp, I
# -> 1313     F = integrate(a*f*exp(b*I*x*k), (x, -oo, oo))
#    1314
#    1315     if not F.has(Integral):
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/integrals.py in integrate(*args, **kwargs)
#    1543
#    1544     if isinstance(integral, Integral):
# -> 1545         return integral.doit(**doit_flags)
#    1546     else:
#    1547         new_args = [a.doit(**doit_flags) if isinstance(a, Integral) else a
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/integrals.py in doit(self, **hints)
#     592                 else:
#     593                     antideriv = self._eval_integral(
# --> 594                         function, xab[0], **eval_kwargs)
#     595                     if antideriv is None and meijerg is True:
#     596                         ret = try_meijerg(function, xab)
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/integrals.py in _eval_integral(self, f, x, meijerg, risch, manual, heurisch, conds)
#    1053                     try:
#    1054                         if conds == 'piecewise':
# -> 1055                             h = heurisch_wrapper(g, x, hints=[])
#    1056                         else:
#    1057                             h = heurisch_(g, x, hints=[])
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/heurisch.py in heurisch_wrapper(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     135
#     136     res = heurisch(f, x, rewrite, hints, mappings, retries, degree_offset,
# --> 137                    unnecessary_permutations, _try_heurisch)
#     138     if not isinstance(res, Basic):
#     139         return res
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     719
#     720     if not (F.free_symbols - set(V)):
# --> 721         solution = _integrate('Q')
#     722
#     723         if solution is None:
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/heurisch.py in _integrate(field)
#     707         ring = PolyRing(V, coeff_ring)
#     708         try:
# --> 709             numer = ring.from_expr(raw_numer)
#     710         except ValueError:
#     711             raise PolynomialError
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in from_expr(self, expr)
#     392
#     393         try:
# --> 394             poly = self._rebuild_expr(expr, mapping)
#     395         except CoercionFailed:
#     396             raise ValueError("expected an expression convertible to a polynomial in %s, got %s" % (self, expr))
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in _rebuild_expr(self, expr, mapping)
#     386                 return domain.convert(expr)
#     387
# --> 388         return _rebuild(sympify(expr))
#     389
#     390     def from_expr(self, expr):
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in _rebuild(expr)
#     378                 return generator
#     379             elif expr.is_Add:
# --> 380                 return reduce(add, list(map(_rebuild, expr.args)))
#     381             elif expr.is_Mul:
#     382                 return reduce(mul, list(map(_rebuild, expr.args)))
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in _rebuild(expr)
#     380                 return reduce(add, list(map(_rebuild, expr.args)))
#     381             elif expr.is_Mul:
# --> 382                 return reduce(mul, list(map(_rebuild, expr.args)))
#     383             elif expr.is_Pow and expr.exp.is_Integer and expr.exp >= 0:
#     384                 return _rebuild(expr.base)**int(expr.exp)
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in _rebuild(expr)
#     378                 return generator
#     379             elif expr.is_Add:
# --> 380                 return reduce(add, list(map(_rebuild, expr.args)))
#     381             elif expr.is_Mul:
#     382                 return reduce(mul, list(map(_rebuild, expr.args)))
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in _rebuild(expr)
#     380                 return reduce(add, list(map(_rebuild, expr.args)))
#     381             elif expr.is_Mul:
# --> 382                 return reduce(mul, list(map(_rebuild, expr.args)))
#     383             elif expr.is_Pow and expr.exp.is_Integer and expr.exp >= 0:
#     384                 return _rebuild(expr.base)**int(expr.exp)
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in __mul__(p1, p2)
#    1094                 for exp2, v2 in p2it:
#    1095                     exp = monomial_mul(exp1, exp2)
# -> 1096                     p[exp] = get(exp, zero) + v1*v2
#    1097             p.strip_zero()
#    1098             return p
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in __add__(p1, p2)
#     933             zero = ring.domain.zero
#     934             for k, v in p2.items():
# --> 935                 v = get(k, zero) + v
#     936                 if v:
#     937                     p[k] = v
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/domains/expressiondomain.py in __add__(f, g)
#      67
#      68             if g is not None:
# ---> 69                 return f.simplify(f.ex + g.ex)
#      70             else:
#      71                 return NotImplemented
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/domains/expressiondomain.py in simplify(f, ex)
#      49
#      50         def simplify(f, ex):
# ---> 51             return f.__class__(ex.cancel().expand(**eflags))
#      52
#      53         def __abs__(f):
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/core/expr.py in cancel(self, *gens, **args)
#    3595         """See the cancel function in sympy.polys"""
#    3596         from sympy.polys import cancel
# -> 3597         return cancel(self, *gens, **args)
#    3598
#    3599     def invert(self, g, *gens, **args):
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/polytools.py in cancel(f, *gens, **args)
#    6698
#    6699     if not isinstance(f, (tuple, Tuple)):
# -> 6700         return c*(P.as_expr()/Q.as_expr())
#    6701     else:
#    6702         if not opt.polys:
#
# KeyboardInterrupt:

# %%
fc1_1 = sp.cos(2*sp.pi*k*x) * fc1
display(fc1_1)
sp.integrate(fc1_1, (k, -sp.oo, sp.oo))
# Out:
# cos(2*pi*k*x)/sqrt(1 + exp(-12*pi**2*k**2))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-7e63e88760bf> in <module>
#       1 fc1_1 = sp.cos(2*sp.pi*k*x) * fc1
#       2 display(fc1_1)
# ----> 3 sp.integrate(fc1_1, (k, -sp.oo, sp.oo))
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/integrals.py in integrate(*args, **kwargs)
#    1543
#    1544     if isinstance(integral, Integral):
# -> 1545         return integral.doit(**doit_flags)
#    1546     else:
#    1547         new_args = [a.doit(**doit_flags) if isinstance(a, Integral) else a
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/integrals.py in doit(self, **hints)
#     592                 else:
#     593                     antideriv = self._eval_integral(
# --> 594                         function, xab[0], **eval_kwargs)
#     595                     if antideriv is None and meijerg is True:
#     596                         ret = try_meijerg(function, xab)
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/integrals.py in _eval_integral(self, f, x, meijerg, risch, manual, heurisch, conds)
#    1053                     try:
#    1054                         if conds == 'piecewise':
# -> 1055                             h = heurisch_wrapper(g, x, hints=[])
#    1056                         else:
#    1057                             h = heurisch_(g, x, hints=[])
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/heurisch.py in heurisch_wrapper(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     135
#     136     res = heurisch(f, x, rewrite, hints, mappings, retries, degree_offset,
# --> 137                    unnecessary_permutations, _try_heurisch)
#     138     if not isinstance(res, Basic):
#     139         return res
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     719
#     720     if not (F.free_symbols - set(V)):
# --> 721         solution = _integrate('Q')
#     722
#     723         if solution is None:
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/heurisch.py in _integrate(field)
#     707         ring = PolyRing(V, coeff_ring)
#     708         try:
# --> 709             numer = ring.from_expr(raw_numer)
#     710         except ValueError:
#     711             raise PolynomialError
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in from_expr(self, expr)
#     392
#     393         try:
# --> 394             poly = self._rebuild_expr(expr, mapping)
#     395         except CoercionFailed:
#     396             raise ValueError("expected an expression convertible to a polynomial in %s, got %s" % (self, expr))
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in _rebuild_expr(self, expr, mapping)
#     386                 return domain.convert(expr)
#     387
# --> 388         return _rebuild(sympify(expr))
#     389
#     390     def from_expr(self, expr):
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in _rebuild(expr)
#     378                 return generator
#     379             elif expr.is_Add:
# --> 380                 return reduce(add, list(map(_rebuild, expr.args)))
#     381             elif expr.is_Mul:
#     382                 return reduce(mul, list(map(_rebuild, expr.args)))
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in _rebuild(expr)
#     380                 return reduce(add, list(map(_rebuild, expr.args)))
#     381             elif expr.is_Mul:
# --> 382                 return reduce(mul, list(map(_rebuild, expr.args)))
#     383             elif expr.is_Pow and expr.exp.is_Integer and expr.exp >= 0:
#     384                 return _rebuild(expr.base)**int(expr.exp)
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in _rebuild(expr)
#     378                 return generator
#     379             elif expr.is_Add:
# --> 380                 return reduce(add, list(map(_rebuild, expr.args)))
#     381             elif expr.is_Mul:
#     382                 return reduce(mul, list(map(_rebuild, expr.args)))
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in _rebuild(expr)
#     380                 return reduce(add, list(map(_rebuild, expr.args)))
#     381             elif expr.is_Mul:
# --> 382                 return reduce(mul, list(map(_rebuild, expr.args)))
#     383             elif expr.is_Pow and expr.exp.is_Integer and expr.exp >= 0:
#     384                 return _rebuild(expr.base)**int(expr.exp)
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in _rebuild(expr)
#     378                 return generator
#     379             elif expr.is_Add:
# --> 380                 return reduce(add, list(map(_rebuild, expr.args)))
#     381             elif expr.is_Mul:
#     382                 return reduce(mul, list(map(_rebuild, expr.args)))
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in _rebuild(expr)
#     380                 return reduce(add, list(map(_rebuild, expr.args)))
#     381             elif expr.is_Mul:
# --> 382                 return reduce(mul, list(map(_rebuild, expr.args)))
#     383             elif expr.is_Pow and expr.exp.is_Integer and expr.exp >= 0:
#     384                 return _rebuild(expr.base)**int(expr.exp)
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in __mul__(p1, p2)
#    1094                 for exp2, v2 in p2it:
#    1095                     exp = monomial_mul(exp1, exp2)
# -> 1096                     p[exp] = get(exp, zero) + v1*v2
#    1097             p.strip_zero()
#    1098             return p
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in __mul__(p1, p2)
#    1094                 for exp2, v2 in p2it:
#    1095                     exp = monomial_mul(exp1, exp2)
# -> 1096                     p[exp] = get(exp, zero) + v1*v2
#    1097             p.strip_zero()
#    1098             return p
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/domains/expressiondomain.py in __mul__(f, g)
#      89
#      90             if g is not None:
# ---> 91                 return f.simplify(f.ex*g.ex)
#      92             else:
#      93                 return NotImplemented
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/core/decorators.py in _func(self, other)
#     249             if not isinstance(other, expectedcls):
#     250                 return retval
# --> 251             return func(self, other)
#     252
#     253         return _func
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/core/decorators.py in binary_op_wrapper(self, other)
#     125                     if f is not None:
#     126                         return f(self)
# --> 127             return func(self, other)
#     128         return binary_op_wrapper
#     129     return priority_decorator
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/core/expr.py in __mul__(self, other)
#     196     @call_highest_priority('__rmul__')
#     197     def __mul__(self, other):
# --> 198         return Mul(self, other)
#     199
#     200     @sympify_return([('other', 'Expr')], NotImplemented)
#
# KeyboardInterrupt:

# %%
fc2_1 = sp.cos(2*sp.pi*k*x) * fc2
display(fc2_1)
sp.integrate(fc2_1, (k, -sp.oo, sp.oo))
# Out:
# cos(2*pi*k*x)/sqrt(exp(12*pi**2*k**2) + 1)
# Integral(cos(2*pi*k*x)/(sqrt(exp(4*pi**2*k**2) + 1)*sqrt(exp(8*pi**2*k**2) - exp(4*pi**2*k**2) + 1)), (k, -oo, oo))

# %%
# Ps is this kind of expressions, 
fp1 = 1/sp.sqrt(1/ftPsf.subs({s1 : 2})**2 + 1/ftPsf.subs({s1 : 1})**2)
display(fp1)
# Out:
# 1/sqrt(exp(16*pi**2*k**2) + exp(4*pi**2*k**2))

# %%
sp.fourier_transform(fp1, k, x)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-d1f94ad7fbc6> in <module>
# ----> 1 sp.fourier_transform(fp1, k, x)
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/transforms.py in fourier_transform(f, x, k, **hints)
#    1405     mellin_transform, laplace_transform
#    1406     """
# -> 1407     return FourierTransform(f, x, k).doit(**hints)
#    1408
#    1409
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/transforms.py in doit(self, **hints)
#     119             try:
#     120                 return self._compute_transform(self.function,
# --> 121                     self.function_variable, self.transform_variable, **hints)
#     122             except IntegralTransformError:
#     123                 pass
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/transforms.py in _compute_transform(self, f, x, k, **hints)
#    1344         return _fourier_transform(f, x, k,
#    1345                                   self.a(), self.b(),
# -> 1346                                   self.__class__._name, **hints)
#    1347
#    1348     def _as_integral(self, f, x, k):
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/transforms.py in wrapper(*args, **kwargs)
#     204         def wrapper(*args, **kwargs):
#     205             noconds = kwargs.pop('noconds', default)
# --> 206             res = func(*args, **kwargs)
#     207             if noconds:
#     208                 return res[0]
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/transforms.py in _fourier_transform(f, x, k, a, b, name, simplify)
#    1311     """
#    1312     from sympy import exp, I
# -> 1313     F = integrate(a*f*exp(b*I*x*k), (x, -oo, oo))
#    1314
#    1315     if not F.has(Integral):
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/integrals.py in integrate(*args, **kwargs)
#    1543
#    1544     if isinstance(integral, Integral):
# -> 1545         return integral.doit(**doit_flags)
#    1546     else:
#    1547         new_args = [a.doit(**doit_flags) if isinstance(a, Integral) else a
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/integrals.py in doit(self, **hints)
#     592                 else:
#     593                     antideriv = self._eval_integral(
# --> 594                         function, xab[0], **eval_kwargs)
#     595                     if antideriv is None and meijerg is True:
#     596                         ret = try_meijerg(function, xab)
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/integrals.py in _eval_integral(self, f, x, meijerg, risch, manual, heurisch, conds)
#    1053                     try:
#    1054                         if conds == 'piecewise':
# -> 1055                             h = heurisch_wrapper(g, x, hints=[])
#    1056                         else:
#    1057                             h = heurisch_(g, x, hints=[])
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/heurisch.py in heurisch_wrapper(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     135
#     136     res = heurisch(f, x, rewrite, hints, mappings, retries, degree_offset,
# --> 137                    unnecessary_permutations, _try_heurisch)
#     138     if not isinstance(res, Basic):
#     139         return res
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     722
#     723         if solution is None:
# --> 724             solution = _integrate()
#     725     else:
#     726         solution = _integrate()
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/integrals/heurisch.py in _integrate(field)
#     707         ring = PolyRing(V, coeff_ring)
#     708         try:
# --> 709             numer = ring.from_expr(raw_numer)
#     710         except ValueError:
#     711             raise PolynomialError
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in from_expr(self, expr)
#     392
#     393         try:
# --> 394             poly = self._rebuild_expr(expr, mapping)
#     395         except CoercionFailed:
#     396             raise ValueError("expected an expression convertible to a polynomial in %s, got %s" % (self, expr))
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in _rebuild_expr(self, expr, mapping)
#     386                 return domain.convert(expr)
#     387
# --> 388         return _rebuild(sympify(expr))
#     389
#     390     def from_expr(self, expr):
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in _rebuild(expr)
#     378                 return generator
#     379             elif expr.is_Add:
# --> 380                 return reduce(add, list(map(_rebuild, expr.args)))
#     381             elif expr.is_Mul:
#     382                 return reduce(mul, list(map(_rebuild, expr.args)))
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in _rebuild(expr)
#     380                 return reduce(add, list(map(_rebuild, expr.args)))
#     381             elif expr.is_Mul:
# --> 382                 return reduce(mul, list(map(_rebuild, expr.args)))
#     383             elif expr.is_Pow and expr.exp.is_Integer and expr.exp >= 0:
#     384                 return _rebuild(expr.base)**int(expr.exp)
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in _rebuild(expr)
#     378                 return generator
#     379             elif expr.is_Add:
# --> 380                 return reduce(add, list(map(_rebuild, expr.args)))
#     381             elif expr.is_Mul:
#     382                 return reduce(mul, list(map(_rebuild, expr.args)))
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in _rebuild(expr)
#     380                 return reduce(add, list(map(_rebuild, expr.args)))
#     381             elif expr.is_Mul:
# --> 382                 return reduce(mul, list(map(_rebuild, expr.args)))
#     383             elif expr.is_Pow and expr.exp.is_Integer and expr.exp >= 0:
#     384                 return _rebuild(expr.base)**int(expr.exp)
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in __mul__(p1, p2)
#    1094                 for exp2, v2 in p2it:
#    1095                     exp = monomial_mul(exp1, exp2)
# -> 1096                     p[exp] = get(exp, zero) + v1*v2
#    1097             p.strip_zero()
#    1098             return p
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/rings.py in __add__(p1, p2)
#     933             zero = ring.domain.zero
#     934             for k, v in p2.items():
# --> 935                 v = get(k, zero) + v
#     936                 if v:
#     937                     p[k] = v
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/domains/expressiondomain.py in __add__(f, g)
#      67
#      68             if g is not None:
# ---> 69                 return f.simplify(f.ex + g.ex)
#      70             else:
#      71                 return NotImplemented
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/domains/expressiondomain.py in simplify(f, ex)
#      49
#      50         def simplify(f, ex):
# ---> 51             return f.__class__(ex.cancel().expand(**eflags))
#      52
#      53         def __abs__(f):
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/core/expr.py in cancel(self, *gens, **args)
#    3595         """See the cancel function in sympy.polys"""
#    3596         from sympy.polys import cancel
# -> 3597         return cancel(self, *gens, **args)
#    3598
#    3599     def invert(self, g, *gens, **args):
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/polytools.py in cancel(f, *gens, **args)
#    6664
#    6665     try:
# -> 6666         (F, G), opt = parallel_poly_from_expr((p, q), *gens, **args)
#    6667     except PolificationFailed:
#    6668         if not isinstance(f, (tuple, Tuple)):
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/polytools.py in parallel_poly_from_expr(exprs, *gens, **args)
#    4310     """Construct polynomials from expressions. """
#    4311     opt = options.build_options(gens, args)
# -> 4312     return _parallel_poly_from_expr(exprs, opt)
#    4313
#    4314
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/polytools.py in _parallel_poly_from_expr(exprs, opt)
#    4363             exprs[i] = exprs[i].as_expr()
#    4364
# -> 4365     reps, opt = _parallel_dict_from_expr(exprs, opt)
#    4366     if not opt.gens:
#    4367         raise PolificationFailed(opt, origs, exprs, True)
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/polyutils.py in _parallel_dict_from_expr(exprs, opt)
#     326         exprs = [ expr.expand() for expr in exprs ]
#     327
# --> 328     if any(expr.is_commutative is False for expr in exprs):
#     329         raise PolynomialError('non-commutative expressions are not supported')
#     330
#
# /ssd/gkovacs/lsstsw/miniconda/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sympy/polys/polyutils.py in <genexpr>(.0)
#     326         exprs = [ expr.expand() for expr in exprs ]
#     327
# --> 328     if any(expr.is_commutative is False for expr in exprs):
#     329         raise PolynomialError('non-commutative expressions are not supported')
#     330
#
# KeyboardInterrupt:
